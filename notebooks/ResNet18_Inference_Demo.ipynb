# %% [markdown]
# # ResNet-18 Inference Demo for CIFAKE
#
# This notebook demonstrates practical inference behavior of the trained ResNet-18 detector without retraining.

# %% [markdown]
# ## Why this demo matters
# - **Screening tool**: the model can quickly triage suspected AI-generated images at scale.
# - **Confidence scores**: high confidence can support automation; low confidence flags uncertain cases.
# - **Robustness limits**: compression, blur, and noise can reduce reliability.
# - **Human review**: low-confidence or corrupted inputs should be reviewed by humans before action.

# %% [markdown]
# ## Run the practical inference script
# Adjust paths below to your local CIFAKE dataset and checkpoint location.

# %%
# !python -m src.demo.resnet18_inference_demo \
  --data_dir /path/to/CIFAKE \
  --checkpoint outputs/resnet18/best_resnet18.pth \
  --output_dir outputs/resnet18_report_figures \
  --num_examples 8 \
  --seed 42

# %% [markdown]
# ## Generated artifacts
# - `outputs/resnet18_report_figures/inference_examples.png`
# - `outputs/resnet18_report_figures/corrupted_inference_examples.png`
# - `outputs/resnet18_report_figures/failure_cases.png`
